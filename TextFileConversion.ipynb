# %% [markdown]
# <a href="https://colab.research.google.com/github/shadabmalikcse/Text-File-Conversion/blob/main/TextFileConversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
data={
    'Filesize':['200MB','400MB','600MB','800MB','1000MB'],
    'C':[12,20,34,45,55],
    'C++':[15,25,36,50,60],
    'Java':[18,30,40,55,70],
    'R':[20,35,45,60,80],
    'Python':[25,40,53,75,100]}
df=pd.DataFrame(data)
print(df)
df['File Size (MB)'] = df['Filesize'].str.replace('MB', '').astype(int)
#print(df)
df.set_index('File Size (MB)', inplace=True)
#print(df)


plt.plot(df.index, df['C'], label='C', marker='o')
plt.plot(df.index, df['C++'], label='C++', marker='o')
plt.plot(df.index, df['Java'], label='Java', marker='o')
plt.plot(df.index, df['R'], label='R', marker='o')
plt.plot(df.index, df['Python'], label='Python', marker='o')
plt.xlabel('File Size (MB)')
plt.ylabel('Time Taken (seconds)')
plt.title('Performance Comparison of Programming Languages')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#   Filesize   C  C++  Java   R  Python
# 0    200MB  12   15    18  20      25
# 1    400MB  20   25    30  35      40
# 2    600MB  34   36    40  45      53
# 3    800MB  45   50    55  60      75
# 4   1000MB  55   60    70  80     100
